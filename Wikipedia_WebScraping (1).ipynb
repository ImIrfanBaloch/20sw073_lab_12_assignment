# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafia-Shaikh-eng/Data-Science-Analytics/blob/main/Wikipedia_WebScraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# Fetch a web page
r = requests.get("https://sw.muet.edu.pk/")
print(r.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<title>Department of Software Engineering</title>
#
#  	    <!-- meta tags for SEO -->
#  	    <meta name="description" content="The first ever software engineering department in any public sector university of pakistan that enables students to develop and enhance the understanding of both theoretical and applied knowledge of the fundamentals of Software Engineering.">
# 		<meta name="keywords" content="Software,software engineering,sw,swe,muet,jamshoro,sindh,university">
# 		<meta name="author" content="SW-MUET">
#
#
# 		<!-- meta tag for bootstrap -->
#      	<meta name="viewport" content="width=device-width, initial-scale=1">
#
# 	   <link rel="icon" href="images/logo.png" type="image/png"/>
#
# 	   <!-- add bootstrap css file -->
#
# ...

# %%
import re

# Remove HTML tags using RegularExpression
pattern = re.compile(r'<.*?>')  # tags look like <...>
print(pattern.sub('', r.text))  # replace them with blank
# Out:
# 	Department of Software Engineering
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	        Home
#
#
# 	        Department
#
#
#
#
# 	        Academics
#
#
# 	          B.E Curriculum Contents
# 	          B.E Course Scheme
# 	          B.E Timetable
#    	          M.E/PhD Courses
# 	          Library
# 	          B.E Lab Experiments
# 	          Lab Rubrics
# 	          Survey Forms
#
#
#
# 	        Downloads
#
#
#
#
# 	        R&D
#
#
# 	          Research & Labs
# 	          Publications
# 	          Projects
# 	          IEEE Chapters
#
#
#
#
#
# 	        People
#
#
# 	          Faculty
# 	          Staff
# 	          Alumni
#
# 	          Committees
#
#
#
#
#
# 	        Contact
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       <!--Slide One - Set the background image for this slide in the line below
#
#
#       -->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Previous
#
#
#
#           Next
#
#
#
#
#
#
#
# 	  Vision Of Department
#
#
# ...

# %%
from bs4 import BeautifulSoup

# %%
# Remove HTML tags using Beautiful Soup library
soup = BeautifulSoup(r.text, "html5lib")
print(soup.get_text())
# Out:
# Data - Wikipedia
# ...

# %%
from bs4 import BeautifulSoup

# %%
#mw-content-container
# Find all articles
summaries = soup.find_all("div", class_="col-lg-4 col-md-4 col-sm-6 col-xs-12")

summaries[0]
# Out:
# <div class="col-lg-4 col-md-4 col-sm-6 col-xs-12">Article 1</div>

# %%
summaries[0].get_text().strip()
# Out:
# 'Article 1'
